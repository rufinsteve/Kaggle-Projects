# %% [markdown]
# <h1> Data Analysis with python </h1>

# %%
import pandas as pd

# %%
# Read the CNH file
CNH = pd.read_excel("C:\\Users\\steve rufin\\Desktop\\Niagara_Revenue.xlsx")

# %%
# Display the CNH DataFrame
CNH
# Out:
#     Arrival Date Arrival Day WE indicator    Capacity Days Out  Sys Rem Dem  \
# 0     2020-06-01         MON              N       432   Actual          NaN
# 1     2020-06-02         TUE              N       432   Actual          NaN
# 2     2020-06-03         WED              N       432   Actual          NaN
# 3     2020-06-04         THU              N       432   Actual          NaN
# 4     2020-06-05         FRI              Y       432   Actual          NaN
# ..           ...         ...            ...       ...      ...          ...
# 372   2021-06-08         TUE              N       432      361       103.13
# 373   2021-06-09         WED              N       432      362       107.72
# 374   2021-06-10         THU              N       432      363       108.94
# 375   2021-06-11         FRI              Y       432      364       509.76
# 376   2021-06-12         SAT              Y       432      365       455.60
#
#      Rem Dem STLY  Applied Rem Dem User Override Event  ...  \
# 0             NaN              NaN             Y     N  ...
# 1             NaN              NaN             Y     N  ...
# 2             NaN              NaN             Y     N  ...
# 3             NaN              NaN             Y     N  ...
# 4             NaN              NaN             Y     N  ...
# ..            ...              ...           ...   ...  ...
# 372          18.0           103.13             N     N  ...
# 373          26.0           107.72             N     N  ...
# 374         490.8           108.94             N     N  ...
# 375           NaN           509.76             N     N  ...
# 376           NaN           455.60             N     N  ...
#
#     Room Collection 3 Rem Dem TY %  Room Collection 3 Rem Dem STLY #  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
# ..                             ...                               ...
# 372                          42.27                             11.00
# 373                          41.57                             16.00
# 374                          38.83                            220.91
# 375                          44.68                               NaN
# 376                          41.51                               NaN
#
#      Room Collection 3 Rem Dem STLY %  Room Collection 4 Hurdle Revenue  \
# 0                                 NaN                              0.00
# 1                                 NaN                              0.00
# 2                                 NaN                              0.00
# 3                                 NaN                              0.00
# 4                                 NaN                              0.00
# ..                                ...                               ...
# 372                             61.00                            243.60
# 373                             62.00                            243.60
# 374                             45.01                            154.92
# 375                               NaN                            240.47
# 376                               NaN                            150.97
#
#      Room Collection 4 Transient OTB TY  Room Collection 4 Transient OTB STLY  \
# 0                                     2                                   NaN
# 1                                     5                                   NaN
# 2                                     4                                   NaN
# 3                                     6                                   NaN
# 4                                     8                                   NaN
# ..                                  ...                                   ...
# 372                                   0                                   NaN
# 373                                   0                                   NaN
# 374                                   0                                   NaN
# 375                                   0                                   NaN
# 376                                   0                                   NaN
#
#      Room Collection 4 Rem DemTY #  Room Collection 4 Rem Dem TY %  \
# 0                              NaN                             NaN
# 1                              NaN                             NaN
# 2                              NaN                             NaN
# 3                              NaN                             NaN
# 4                              NaN                             NaN
# ..                             ...                             ...
# 372                           7.99                            7.75
# 373                           8.13                            7.54
# 374                           7.94                            7.29
# 375                          35.43                            6.95
# 376                          30.83                            6.77
#
#      Room Collection 4 Rem Dem STLY #  Room Collection 4 Rem Dem STLY %
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
# ..                                ...                               ...
# 372                               NaN                               NaN
# 373                              2.00                               8.0
# 374                             38.29                               7.8
# 375                               NaN                               NaN
# 376                               NaN                               NaN
#
# [377 rows x 104 columns]

# %%
# Make a copy of CNH
df = CNH.copy()

# %%
# Display df
df
# Out:
#     Arrival Date Arrival Day WE indicator    Capacity Days Out  Sys Rem Dem  \
# 0     2020-06-01         MON              N       432   Actual          NaN
# 1     2020-06-02         TUE              N       432   Actual          NaN
# 2     2020-06-03         WED              N       432   Actual          NaN
# 3     2020-06-04         THU              N       432   Actual          NaN
# 4     2020-06-05         FRI              Y       432   Actual          NaN
# ..           ...         ...            ...       ...      ...          ...
# 372   2021-06-08         TUE              N       432      361       103.13
# 373   2021-06-09         WED              N       432      362       107.72
# 374   2021-06-10         THU              N       432      363       108.94
# 375   2021-06-11         FRI              Y       432      364       509.76
# 376   2021-06-12         SAT              Y       432      365       455.60
#
#      Rem Dem STLY  Applied Rem Dem User Override Event  ...  \
# 0             NaN              NaN             Y     N  ...
# 1             NaN              NaN             Y     N  ...
# 2             NaN              NaN             Y     N  ...
# 3             NaN              NaN             Y     N  ...
# 4             NaN              NaN             Y     N  ...
# ..            ...              ...           ...   ...  ...
# 372          18.0           103.13             N     N  ...
# 373          26.0           107.72             N     N  ...
# 374         490.8           108.94             N     N  ...
# 375           NaN           509.76             N     N  ...
# 376           NaN           455.60             N     N  ...
#
#     Room Collection 3 Rem Dem TY %  Room Collection 3 Rem Dem STLY #  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
# ..                             ...                               ...
# 372                          42.27                             11.00
# 373                          41.57                             16.00
# 374                          38.83                            220.91
# 375                          44.68                               NaN
# 376                          41.51                               NaN
#
#      Room Collection 3 Rem Dem STLY %  Room Collection 4 Hurdle Revenue  \
# 0                                 NaN                              0.00
# 1                                 NaN                              0.00
# 2                                 NaN                              0.00
# 3                                 NaN                              0.00
# 4                                 NaN                              0.00
# ..                                ...                               ...
# 372                             61.00                            243.60
# 373                             62.00                            243.60
# 374                             45.01                            154.92
# 375                               NaN                            240.47
# 376                               NaN                            150.97
#
#      Room Collection 4 Transient OTB TY  Room Collection 4 Transient OTB STLY  \
# 0                                     2                                   NaN
# 1                                     5                                   NaN
# 2                                     4                                   NaN
# 3                                     6                                   NaN
# 4                                     8                                   NaN
# ..                                  ...                                   ...
# 372                                   0                                   NaN
# 373                                   0                                   NaN
# 374                                   0                                   NaN
# 375                                   0                                   NaN
# 376                                   0                                   NaN
#
#      Room Collection 4 Rem DemTY #  Room Collection 4 Rem Dem TY %  \
# 0                              NaN                             NaN
# 1                              NaN                             NaN
# 2                              NaN                             NaN
# 3                              NaN                             NaN
# 4                              NaN                             NaN
# ..                             ...                             ...
# 372                           7.99                            7.75
# 373                           8.13                            7.54
# 374                           7.94                            7.29
# 375                          35.43                            6.95
# 376                          30.83                            6.77
#
#      Room Collection 4 Rem Dem STLY #  Room Collection 4 Rem Dem STLY %
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
# ..                                ...                               ...
# 372                               NaN                               NaN
# 373                              2.00                               8.0
# 374                             38.29                               7.8
# 375                               NaN                               NaN
# 376                               NaN                               NaN
#
# [377 rows x 104 columns]

# %% [markdown]
# <h3> Exploratory analysis </h3>

# %%
# describe df
df.describe()
# Out:
#        Capacity  Sys Rem Dem  Rem Dem STLY  Applied Rem Dem  \
# count     377.0   366.000000    364.000000       366.000000
# mean      432.0   168.166885    211.058077       163.475574
# std         0.0   125.139357    157.277895       118.867674
# min       432.0    17.850000      0.260000        17.850000
# 25%       432.0    62.542500     62.550000        62.542500
# 50%       432.0   105.205000    193.105000       106.515000
# 75%       432.0   280.860000    357.235000       271.000000
# max       432.0   509.760000    569.880000       521.000000
#
#        Total Available Transient Supply  Total Transient Booked  \
# count                        377.000000              301.000000
# mean                         395.264960               22.016611
# std                           42.579159               20.904299
# min                          186.860000                1.000000
# 25%                          380.040000                3.000000
# 50%                          407.000000               13.000000
# 75%                          429.820000               40.000000
# max                          432.320000              103.000000
#
#        Total Transient Booked STLY  Additional Demand  Additional Demand STLY  \
# count                   338.000000         148.000000              338.000000
# mean                     90.748521          19.990608               21.480030
# std                     120.876345          17.375392               41.603572
# min                       1.000000           0.230000                0.000000
# 25%                       5.000000           8.152500                0.000000
# 50%                      15.000000          15.760000                0.445000
# 75%                     144.750000          27.487500               23.877500
# max                     438.000000          88.730000              262.160000
#
#        Total Transient Demand  ...  Room Collection 3 Rem Dem TY %  \
# count              377.000000  ...                      366.000000
# mean               184.131592  ...                       36.811202
# std                125.946725  ...                        7.874366
# min                 32.640000  ...                       15.130000
# 25%                 78.600000  ...                       31.545000
# 50%                135.450000  ...                       37.415000
# 75%                298.920000  ...                       41.215000
# max                534.000000  ...                       72.030000
#
#        Room Collection 3 Rem Dem STLY #  Room Collection 3 Rem Dem STLY %  \
# count                        363.000000                        363.000000
# mean                          79.638099                         38.945730
# std                           61.443453                          9.802116
# min                            1.000000                          6.000000
# 25%                           25.140000                         33.340000
# 50%                           64.910000                         38.000000
# 75%                          130.545000                         43.000000
# max                          241.910000                         81.000000
#
#        Room Collection 4 Hurdle Revenue  Room Collection 4 Transient OTB TY  \
# count                        377.000000                          377.000000
# mean                           4.322149                            1.501326
# std                           29.841123                            2.253985
# min                            0.000000                            0.000000
# 25%                            0.000000                            0.000000
# 50%                            0.000000                            0.000000
# 75%                            0.000000                            3.000000
# max                          243.600000                           20.000000
#
#        Room Collection 4 Transient OTB STLY  Room Collection 4 Rem DemTY #  \
# count                            219.000000                     366.000000
# mean                               7.301370                      10.430437
# std                                8.590081                       7.423298
# min                                1.000000                       1.040000
# 25%                                1.000000                       4.032500
# 50%                                4.000000                       7.575000
# 75%                               10.000000                      17.592500
# max                               48.000000                      35.430000
#
#        Room Collection 4 Rem Dem TY %  Room Collection 4 Rem Dem STLY #  \
# count                      366.000000                        356.000000
# mean                         6.785437                         16.735197
# std                          2.862946                         13.024180
# min                          2.800000                          0.260000
# 25%                          5.522500                          5.412500
# 50%                          6.275000                         13.340000
# 75%                          7.042500                         25.942500
# max                         22.120000                         62.880000
#
#        Room Collection 4 Rem Dem STLY %
# count                        356.000000
# mean                           9.489775
# std                            7.466831
# min                            1.000000
# 25%                            6.000000
# 50%                            7.850000
# 75%                           10.477500
# max                          100.000000
#
# [8 rows x 97 columns]

# %%
# display the first 5 rows of df
df.head()
# Out:
#   Arrival Date Arrival Day WE indicator    Capacity Days Out  Sys Rem Dem  \
# 0   2020-06-01         MON              N       432   Actual          NaN
# 1   2020-06-02         TUE              N       432   Actual          NaN
# 2   2020-06-03         WED              N       432   Actual          NaN
# 3   2020-06-04         THU              N       432   Actual          NaN
# 4   2020-06-05         FRI              Y       432   Actual          NaN
#
#    Rem Dem STLY  Applied Rem Dem User Override Event  ...  \
# 0           NaN              NaN             Y     N  ...
# 1           NaN              NaN             Y     N  ...
# 2           NaN              NaN             Y     N  ...
# 3           NaN              NaN             Y     N  ...
# 4           NaN              NaN             Y     N  ...
#
#   Room Collection 3 Rem Dem TY %  Room Collection 3 Rem Dem STLY #  \
# 0                            NaN                               NaN
# 1                            NaN                               NaN
# 2                            NaN                               NaN
# 3                            NaN                               NaN
# 4                            NaN                               NaN
#
#    Room Collection 3 Rem Dem STLY %  Room Collection 4 Hurdle Revenue  \
# 0                               NaN                               0.0
# 1                               NaN                               0.0
# 2                               NaN                               0.0
# 3                               NaN                               0.0
# 4                               NaN                               0.0
#
#    Room Collection 4 Transient OTB TY  Room Collection 4 Transient OTB STLY  \
# 0                                   2                                   NaN
# 1                                   5                                   NaN
# 2                                   4                                   NaN
# 3                                   6                                   NaN
# 4                                   8                                   NaN
#
#    Room Collection 4 Rem DemTY #  Room Collection 4 Rem Dem TY %  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
#
#    Room Collection 4 Rem Dem STLY #  Room Collection 4 Rem Dem STLY %
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
# [5 rows x 104 columns]

# %%
# Display the last 5 rows of df
df.tail()
# Out:
#     Arrival Date Arrival Day WE indicator    Capacity Days Out  Sys Rem Dem  \
# 372   2021-06-08         TUE              N       432      361       103.13
# 373   2021-06-09         WED              N       432      362       107.72
# 374   2021-06-10         THU              N       432      363       108.94
# 375   2021-06-11         FRI              Y       432      364       509.76
# 376   2021-06-12         SAT              Y       432      365       455.60
#
#      Rem Dem STLY  Applied Rem Dem User Override Event  ...  \
# 372          18.0           103.13             N     N  ...
# 373          26.0           107.72             N     N  ...
# 374         490.8           108.94             N     N  ...
# 375           NaN           509.76             N     N  ...
# 376           NaN           455.60             N     N  ...
#
#     Room Collection 3 Rem Dem TY %  Room Collection 3 Rem Dem STLY #  \
# 372                          42.27                             11.00
# 373                          41.57                             16.00
# 374                          38.83                            220.91
# 375                          44.68                               NaN
# 376                          41.51                               NaN
#
#      Room Collection 3 Rem Dem STLY %  Room Collection 4 Hurdle Revenue  \
# 372                             61.00                            243.60
# 373                             62.00                            243.60
# 374                             45.01                            154.92
# 375                               NaN                            240.47
# 376                               NaN                            150.97
#
#      Room Collection 4 Transient OTB TY  Room Collection 4 Transient OTB STLY  \
# 372                                   0                                   NaN
# 373                                   0                                   NaN
# 374                                   0                                   NaN
# 375                                   0                                   NaN
# 376                                   0                                   NaN
#
#      Room Collection 4 Rem DemTY #  Room Collection 4 Rem Dem TY %  \
# 372                           7.99                            7.75
# 373                           8.13                            7.54
# 374                           7.94                            7.29
# 375                          35.43                            6.95
# 376                          30.83                            6.77
#
#      Room Collection 4 Rem Dem STLY #  Room Collection 4 Rem Dem STLY %
# 372                               NaN                               NaN
# 373                              2.00                               8.0
# 374                             38.29                               7.8
# 375                               NaN                               NaN
# 376                               NaN                               NaN
#
# [5 rows x 104 columns]
